# %% [markdown]
# # Q1 Create a calculated column  Total Price using Quantity and Unit Price
#
# answer![Screenshot 2026-03-02 181329.png](data:image/png;base64,...)

# %% [markdown]
# # Q2 Create a calculated column using DiscountedPrice
#
# answer
#
# ![Screenshot 2026-03-02 181830.png](data:image/png;base64,...)

# %% [markdown]
# # 3  Create a measure  AVERAGE ORDER VALUE
#
# ANSWER
#
#
# ![Screenshot 2026-03-02 183217.png](data:image/png;base64,...)

# %% [markdown]
# # 4 Using DAX, create a measure that calculates cumulative Year-to-Date (YTD) Sales based on the Order Date
#
#
#
# ANSWER
# ![Screenshot 2026-03-02 184349.png](data:image/png;base64,...)

# %% [markdown]
# # Q5 Using DAX, create a measure to rank each product according to its Total Sales, with the highest-selling product ranked first
#
#
# ANSWER
#
# ![Screenshot 2026-03-02 185726.png](data:image/png;base64,...)

# %% [markdown]
# # Q6 Create a calculated column classifying orders as “High Value” if sales > 2000, else “Low Value”
#
# ANSWER
# ![Screenshot 2026-03-02 190458.png](data:image/png;base64,...)

# %% [markdown]
# # Q 7 Create a measure to calculate total sales from the Online channel only
#
# ANSWER
#
# ![Screenshot 2026-03-02 191003.png](data:image/png;base64,...)

# %% [markdown]
# # Create a measure called "Date Difference" that calculates the number of days between the latest  Order Date and today's date using the DATEDIFF function.
#
# ANSWER
#
# ![Screenshot 2026-03-02 191647.png](data:image/png;base64,...)
