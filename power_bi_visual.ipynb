# %% [markdown]
# # Question 1 : Create a Card Visual to show Total Sales.
#
#
# ![Screenshot 2026-02-23 100400.png](data:image/png;base64,...)

# %% [markdown]
# # Question 2  : Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the  highest sales?
#
# ANSWER
# 1. STANDARD CLASS GENERATE HIGHEST SALE = 7.58M
#
# ![Screenshot 2026-02-23 101252.png](data:image/png;base64,...)

# %% [markdown]
# # Question 3 : Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any  noticeable seasonal pattern in sales?
#
# ANSWER
#
# 1. The Line Chart shows that sales increase towards the end of each year, specially in November and December. This indicates a seasonal pattern where sales are higher during the holiday season and lower at the beginning of the year.
#
# ![Screenshot 2026-02-23 102650.png](data:image/png;base64,...)

# %% [markdown]
# # Question 4 : Create a Bar Chart to compare Sales by Category
#
# ANSWER
#
# 1. Technology has the highest sales
# 2. Second: FURNITURE
# 3. Third: OFFICE SUPPLIER
#
#
# ![Screenshot 2026-02-23 103407.png](data:image/png;base64,...)

# %% [markdown]
# # Question 5 : Create a Matrix Visual to display Sales by Month and Category and identify the month with the  highest sales.
#
# ANSWER
#
# 1. DECEMBER  has the highest sales
# 2. NOVEMBER is usually second highest
#
# ![Screenshot 2026-02-23 103821.png](data:image/png;base64,...)

# %% [markdown]
# # Question 6 : Create a Decomposition Tree for Sales Breakdown.
#
# ANSWER
#
#
# ![Screenshot 2026-02-23 105229.png](data:image/png;base64,...)

# %% [markdown]
# # Question 7 : Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers where high discounts resulted in negative profit?
#
# ANSWER
# 1. Scatter Chart was created using Discount on X-axis and Profit on Y-axis with Sub-Category in Legend. The chart shows that some sub-categories like Tables and Bookcases have high discounts but negative profit, indicating outliers where discounts resulted in losses.
#
# ![Screenshot 2026-02-23 110019.png](data:image/png;base64,...)

# %% [markdown]
# # Question 8 : Use a Funnel Chart to show the number of orders by Customer Segment.
#
# 1. CONSUMER HIGHEST
# 2. CORPORATE = MIDDLE
# 3. HOME OFFICE = SMALLEST
#
# ![Screenshot 2026-02-23 110537.png](data:image/png;base64,...)

# %% [markdown]
# # Question 9 : Use a Waterfall Chart to analyze how Profit changes by Category within the countries
#
# ANSWER
# 1. A Waterfall Chart was created using Country in Category, Profit in Y-axis, and Category in Breakdown. The chart shows how profit changes across categories within each country. Technology contributes the most to profit, while Furniture contributes less in some countries.
#
#
#
# ![Screenshot 2026-02-23 111647.png](data:image/png;base64,...)

# %% [markdown]
# # Question 10 : Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month)
#
# ANSWER
#
# 1. Sales and Profit both increase over time. Profit follows similar trend as Sales, showing business growth.
#
# ![Screenshot 2026-02-23 114551.png](data:image/png;base64,...)
